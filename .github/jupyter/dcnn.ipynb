# %%
# https://github.com/42io/dataset/tree/master/google_speech_commands#numpy-example
DATASET_FILE = '1gmnWx2we0I-RNiWSvIRN7RzUrJrSp_uQ' # 0-9up.npz

# %%
# !test -f "$DATASET_FILE" || gdown --id "$DATASET_FILE" -O "$DATASET_FILE"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gmnWx2we0I-RNiWSvIRN7RzUrJrSp_uQ
# To: /content/1gmnWx2we0I-RNiWSvIRN7RzUrJrSp_uQ
# 5.63GB [01:55, 48.7MB/s]

# %%
import subprocess
assert(b'cb126d837b86b1f6baf5c8268804877a' == subprocess.run(['md5sum', DATASET_FILE], stdout=subprocess.PIPE).stdout.split()[0])

# %%
# %tensorflow_version 2.x
import numpy as np
from tensorflow import keras as keras
# !nvidia-smi
# Out:
# TensorFlow 2.x selected.
# Sat Mar  7 21:23:26 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# see https://github.com/42io/dataset/tree/master/google_speech_commands#numpy-example
dset = np.load(DATASET_FILE)
print(dset['x_train'].shape)
# Out:
# (1095480, 637)

# %%
x_train_4d = dset['x_train'].reshape(len(dset['x_train']), 49, 13, 1)
x_test_4d = dset['x_test'].reshape(len(dset['x_test']), 49, 13, 1)
x_valid_4d = dset['x_valid'].reshape(len(dset['x_valid']), 49, 13, 1)

# %%
x_in = keras.Input(shape=(49, 13, 1))

x = keras.layers.Conv2D(64, kernel_size=(13, 8), use_bias=False)(x_in)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.SpatialDropout2D(0.1)(x)

x = keras.layers.DepthwiseConv2D(kernel_size=(8, 6), use_bias=False)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.Conv2D(128, kernel_size=(1, 1), use_bias=False)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.SpatialDropout2D(0.1)(x)

x = keras.layers.MaxPooling2D(pool_size=(30, 1))(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dense(128, use_bias=False)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.ReLU()(x)
x = keras.layers.Dropout(0.2)(x)
x = keras.layers.Dense(12, activation='softmax')(x)

model = keras.Model(inputs=x_in, outputs=x)

model.summary()

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

early_stopping = keras.callbacks.EarlyStopping(
        monitor='val_loss',
        mode='min',
        verbose=1,
        patience=100,
        restore_best_weights=True)

history = model.fit(x_train_4d,
                    keras.utils.to_categorical(dset['y_train']),
                    validation_data=(x_valid_4d, keras.utils.to_categorical(dset['y_valid'])),
                    callbacks=[early_stopping],
                    verbose=2,
                    epochs=100500)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 49, 13, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 6, 64)         6656
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 37, 6, 64)         256
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 37, 6, 64)         0
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 37, 6, 64)         0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 30, 1, 64)         3072
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30, 1, 64)         256
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 30, 1, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 1, 128)        8192
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 30, 1, 128)        512
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 30, 1, 128)        0
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 30, 1, 128)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16384
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                1548
# =================================================================
# Total params: 37,388
# Trainable params: 36,620
# Non-trainable params: 768
# _________________________________________________________________
# Train on 1095480 samples, validate on 3368 samples
# Epoch 1/100500
# 1095480/1095480 - 146s - loss: 0.2525 - accuracy: 0.9203 - val_loss: 0.1041 - val_accuracy: 0.9685
# Epoch 2/100500
# 1095480/1095480 - 142s - loss: 0.1550 - accuracy: 0.9509 - val_loss: 0.0869 - val_accuracy: 0.9754
# Epoch 3/100500
# 1095480/1095480 - 143s - loss: 0.1364 - accuracy: 0.9566 - val_loss: 0.0913 - val_accuracy: 0.9760
# Epoch 4/100500
# 1095480/1095480 - 143s - loss: 0.1265 - accuracy: 0.9595 - val_loss: 0.0844 - val_accuracy: 0.9762
# Epoch 5/100500
# 1095480/1095480 - 141s - loss: 0.1199 - accuracy: 0.9615 - val_loss: 0.0812 - val_accuracy: 0.9760
# Epoch 6/100500
# 1095480/1095480 - 145s - loss: 0.1147 - accuracy: 0.9634 - val_loss: 0.0823 - val_accuracy: 0.9757
# Epoch 7/100500
# 1095480/1095480 - 149s - loss: 0.1110 - accuracy: 0.9645 - val_loss: 0.0845 - val_accuracy: 0.9786
# Epoch 8/100500
# 1095480/1095480 - 149s - loss: 0.1079 - accuracy: 0.9654 - val_loss: 0.0740 - val_accuracy: 0.9807
# Epoch 9/100500
# 1095480/1095480 - 149s - loss: 0.1052 - accuracy: 0.9664 - val_loss: 0.0750 - val_accuracy: 0.9777
# Epoch 10/100500
# 1095480/1095480 - 146s - loss: 0.1031 - accuracy: 0.9669 - val_loss: 0.0706 - val_accuracy: 0.9786
# Epoch 11/100500
# 1095480/1095480 - 141s - loss: 0.1011 - accuracy: 0.9675 - val_loss: 0.0752 - val_accuracy: 0.9771
# Epoch 12/100500
# 1095480/1095480 - 142s - loss: 0.0994 - accuracy: 0.9682 - val_loss: 0.0737 - val_accuracy: 0.9795
# Epoch 13/100500
# 1095480/1095480 - 141s - loss: 0.0980 - accuracy: 0.9684 - val_loss: 0.0773 - val_accuracy: 0.9783
# Epoch 14/100500
# 1095480/1095480 - 142s - loss: 0.0971 - accuracy: 0.9688 - val_loss: 0.0753 - val_accuracy: 0.9780
# Epoch 15/100500
# 1095480/1095480 - 142s - loss: 0.0965 - accuracy: 0.9690 - val_loss: 0.0782 - val_accuracy: 0.9801
# Epoch 16/100500
# 1095480/1095480 - 143s - loss: 0.0949 - accuracy: 0.9696 - val_loss: 0.0708 - val_accuracy: 0.9807
# Epoch 17/100500
# 1095480/1095480 - 141s - loss: 0.0942 - accuracy: 0.9698 - val_loss: 0.0734 - val_accuracy: 0.9798
# Epoch 18/100500
# 1095480/1095480 - 141s - loss: 0.0923 - accuracy: 0.9703 - val_loss: 0.0810 - val_accuracy: 0.9792
# Epoch 19/100500
# 1095480/1095480 - 143s - loss: 0.0923 - accuracy: 0.9703 - val_loss: 0.0730 - val_accuracy: 0.9807
# Epoch 20/100500
# 1095480/1095480 - 144s - loss: 0.0910 - accuracy: 0.9707 - val_loss: 0.0738 - val_accuracy: 0.9792
# Epoch 21/100500
# 1095480/1095480 - 146s - loss: 0.0904 - accuracy: 0.9711 - val_loss: 0.0761 - val_accuracy: 0.9786
# Epoch 22/100500
# 1095480/1095480 - 142s - loss: 0.0904 - accuracy: 0.9709 - val_loss: 0.0767 - val_accuracy: 0.9792
# Epoch 23/100500
# 1095480/1095480 - 141s - loss: 0.0895 - accuracy: 0.9712 - val_loss: 0.0682 - val_accuracy: 0.9810
# Epoch 24/100500
# Epoch 213/100500
# 1095480/1095480 - 135s - loss: 0.0695 - accuracy: 0.9776 - val_loss: 0.0616 - val_accuracy: 0.9846
# Epoch 214/100500
# 1095480/1095480 - 137s - loss: 0.0698 - accuracy: 0.9774 - val_loss: 0.0616 - val_accuracy: 0.9834
# Epoch 215/100500
# 1095480/1095480 - 138s - loss: 0.0694 - accuracy: 0.9776 - val_loss: 0.0604 - val_accuracy: 0.9852
# Epoch 216/100500
# 1095480/1095480 - 137s - loss: 0.0688 - accuracy: 0.9778 - val_loss: 0.0544 - val_accuracy: 0.9843
# Epoch 217/100500
# 1095480/1095480 - 139s - loss: 0.0696 - accuracy: 0.9775 - val_loss: 0.0594 - val_accuracy: 0.9834
# Epoch 218/100500
# 1095480/1095480 - 137s - loss: 0.0694 - accuracy: 0.9777 - val_loss: 0.0567 - val_accuracy: 0.9828
# Epoch 219/100500
# 1095480/1095480 - 137s - loss: 0.0697 - accuracy: 0.9774 - val_loss: 0.0587 - val_accuracy: 0.9837
# Epoch 220/100500
# 1095480/1095480 - 136s - loss: 0.0690 - accuracy: 0.9778 - val_loss: 0.0617 - val_accuracy: 0.9828
# Epoch 221/100500
# 1095480/1095480 - 136s - loss: 0.0696 - accuracy: 0.9775 - val_loss: 0.0608 - val_accuracy: 0.9834
# Epoch 222/100500
# 1095480/1095480 - 136s - loss: 0.0695 - accuracy: 0.9776 - val_loss: 0.0617 - val_accuracy: 0.9831
# Epoch 223/100500
# Restoring model weights from the end of the best epoch.
# 1095480/1095480 - 137s - loss: 0.0694 - accuracy: 0.9774 - val_loss: 0.0588 - val_accuracy: 0.9869
# Epoch 00223: early stopping

# %%
print(history.history.keys())

import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
results = model.evaluate(x_train_4d, keras.utils.to_categorical(dset['y_train']), verbose=0)
print('train loss, train acc:', results)

results = model.evaluate(x_test_4d, keras.utils.to_categorical(dset['y_test']), verbose=0)
print('test loss, test acc:', results)

results = model.evaluate(x_valid_4d, keras.utils.to_categorical(dset['y_valid']), verbose=0)
print('valid loss, valid acc:', results)
# Out:
# train loss, train acc: [0.023058404257247363, 0.9926836]
# test loss, test acc: [0.08532818567678935, 0.9756162]
# valid loss, valid acc: [0.05332257811874212, 0.9848575]

# %%
assert(len(x_test_4d) + len(x_valid_4d) == 7141)
pred = model.predict(x_test_4d).argmax(axis=-1)
print(np.sum(pred != dset['y_test']), len(pred))
pred = model.predict(x_valid_4d).argmax(axis=-1)
print(np.sum(pred != dset['y_valid']), len(pred))
# Out:
# 92 3773
# 51 3368

# %%
import tensorflow as tf
print(tf.__version__)

# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# 2.1.0

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
# !mkdir -p '/content/gdrive/My Drive/kws/models'
with open("/content/gdrive/My Drive/kws/models/dcnn.tflite", "wb") as f:
  f.write(tflite_model)
# !md5sum "/content/gdrive/My Drive/kws/models/dcnn.tflite"
# Out:
# fca521326f57c257329085ed90b2edc1  /content/gdrive/My Drive/kws/models/dcnn.tflite
